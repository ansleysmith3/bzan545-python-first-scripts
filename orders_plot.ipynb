# %% [markdown]
# # Orders plot notebook
#
# Same tiny analysis as `orders_plot.py`, but in notebook form.

# %% [markdown]
# bold text
# some text

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv("data/orders.csv")
orders.head()
# Out:
#    order_id  order_date     customer_name state                 product  \
# 0      1001  2026-07-21  Steven Blackwell    TN  Volunteer Sticker Pack
# 1      1002  2026-07-03      Yolanda Hall    VA  Volunteer Sticker Pack
# 2      1003  2026-07-20   Herbert Padilla    GA      Orange Dog Bandana
# 3      1004  2026-07-11     Crystal Olsen    GA  Volunteer Sticker Pack
# 4      1005  2026-07-04      Devin Steele    NC         Tailgate Cooler
#
#       category  quantity  unit_price  order_total
# 0  accessories         6         6.0         36.0
# 1  accessories         4         6.0         24.0
# 2  accessories         3        14.0         42.0
# 3  accessories         2         6.0         12.0
# 4         gear         4        72.0        288.0

# %%
orders.shape
# Out:
# (150, 9)

# %%
sns.scatterplot(x="quantity", y="order_total", hue="category", data=orders)
plt.show()
